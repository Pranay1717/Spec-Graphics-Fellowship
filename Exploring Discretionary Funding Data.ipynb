# %% [markdown]
# Goal is to look into discretionary funding data from West Harlem, MoHi, and nearby areas. Are there are any disparities in the amounts of money allocated based on geographic location or any other feature?
#
# Ultimately should try to find some way in which resource allocation is correlated to the zoning. Could also be the case that specific types of zoning (ex. private land vs commercial etc.) affect only a few types of resource allocation like education funding. So, should also try to look at trends in funding among programs like education.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import pandas as pd
import os
from sodapy import Socrata

# %%
socrata_domain = 'data.cityofnewyork.us'
socrata_dataset_identifier = '4d7f-74pe'
socrata_token = None

# %%
client = Socrata(socrata_domain, socrata_token)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**client.__dict__))
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Domain: data.cityofnewyork.us
# Session: <requests.sessions.Session object at 0x000001EB5C402188>
# URI Prefix: https://

# %%
results = client.get(socrata_dataset_identifier)
df = pd.DataFrame.from_dict(results)
display(df.head())
print(df.size)
# Out:
#      mocs_id fiscal_year                                     source  \
# 0  FY19 8307        2019                              Food Pantries
# 1  FY19 6733        2019  Neighborhood Development Grant Initiative
# 2  FY19 1403        2019                                      Local
# 3  FY19 8167        2019                              Food Pantries
# 4  FY19 1900        2019                                      Local
#
#         council_member                         legal_name_of_organization  \
# 0  Brooklyn Delegation  National Committee for the Furtherance of Jewi...
# 1                 Rose                    Bayview Community Council, Inc.
# 2               Kallos                 Department of Emergency Management
# 3    Queens Delegation                        Food Bank For New York City
# 4                Ayala                  Getting Out and Staying Out, Inc.
#
#          ein   status amount agency  \
# 0  116003180  Cleared  15000   DYCD
# ...

# %%
council7_df=df.loc[df['council_district'] == "7"]
display(council7_df.head())
print(council7_df.size)
# Out:
#        mocs_id fiscal_year                                source  \
# 106  FY19 5503        2019    Immigrant Opportunities Initiative
# 205  FY19 0375        2019                                 Local
# 235  FY19 9276        2019  Young Women's Leadership Development
# 348  FY19 0448        2019                                 Local
# 479  FY19 4723        2019                                 Youth
#
#     council_member           legal_name_of_organization        ein   status  \
# 106            NaN     African Services Committee, Inc.  133749744  Cleared
# 205      Rodriguez                         BioBus, Inc.  262092282  Cleared
# 235            NaN    Brotherhood Sister Sol, Inc., The  133857387  Cleared
# 348        Speaker  Boys and Girls Club of Harlem, Inc.  133102951  Cleared
# 479         Levine            Wendy Hilliard Foundation  133879321  Cleared
#
#     amount   agency                           program_name  ...    borough  \
# ...

# %%
display(council7_df[["amount","nta"]])
print(council7_df[["amount","nta"]].size)
# Out:
#      amount                  nta
# 106   27000       Manhattanville
# 205    3500       Manhattanville
# 235   29375     Hamilton Heights
# 348   25000     Hamilton Heights
# 479   10000     Hamilton Heights
# 508   78940       Manhattanville
# 808    4000       Manhattanville
# 903  125000     Hamilton Heights
# 978    5000  Morningside Heights
# 18
